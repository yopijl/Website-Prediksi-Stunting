# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Membaca data dari file Excel
data = pd.read_excel("/content/drive/MyDrive/RTI/data_balita.xlsx")

# %%
# Preprocessing data
le = LabelEncoder()
data['Jenis Kelamin'] = le.fit_transform(data['Jenis Kelamin'])

# %%
# Memisahkan fitur dan target
X = data.drop(columns=['Status Gizi'])
y = data['Status Gizi']

# %%
# Standarisasi fitur
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Membagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Pembangunan Model Random Forest
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Evaluasi Model pada data training
y_pred_train = model.predict(X_train)
print("Classification Report untuk Data Training:")
print(classification_report(y_train, y_pred_train))
# Out:
# Classification Report untuk Data Training:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     54373
#            1       1.00      1.00      1.00     15662
#            2       1.00      1.00      1.00     11025
#            3       1.00      1.00      1.00     15739
#
#     accuracy                           1.00     96799
#    macro avg       1.00      1.00      1.00     96799
# weighted avg       1.00      1.00      1.00     96799

# %%
# Evaluasi Model
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13382
#            1       1.00      1.00      1.00      3898
#            2       1.00      1.00      1.00      2790
#            3       1.00      1.00      1.00      4130
#
#     accuracy                           1.00     24200
#    macro avg       1.00      1.00      1.00     24200
# weighted avg       1.00      1.00      1.00     24200

# %%
# Simpan Model sebagai .pkl
pickle.dump(model, open("model.pkl", "wb"))

# %%
model=pickle.load(open("model.pkl", "rb"))
